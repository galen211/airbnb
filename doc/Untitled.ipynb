# %%
import turicreate as tc

# %%
import os
from os.path import join

nb_path = os.getcwd() # should be the location of the pynb file
root_path = os.path.split(nb_path)[0] # project root
data_path = os.path.join(root_path, "data") # for data
lib_path = os.path.join(root_path, "lib") # for python scripts
model_path = os.path.join(root_path, "data", "model")

print("root path: " + root_path)
print("data path: " + data_path)
print("model path: " + model_path)
# Out:
# root path: /Users/galen/Documents/airbnb
# data path: /Users/galen/Documents/airbnb/data
# model path: /Users/galen/Documents/airbnb/data/model

# %%
train = tc.SFrame.read_csv(os.path.join(data_path,'train.csv'), verbose=False)
test = tc.SFrame.read_csv(os.path.join(data_path,'test.csv'), verbose=False)

# %%
train.head()
# Out:
# Columns:
# 	id	int
# 	log_price	float
# 	property_type	str
# 	room_type	str
# 	amenities	str
# 	accommodates	int
# 	bathrooms	float
# 	bed_type	str
# 	cancellation_policy	str
# 	cleaning_fee	str
# 	city	str
# 	description	str
# 	first_review	str
# 	host_has_profile_pic	str
# 	host_identity_verified	str
# 	host_response_rate	str
# 	host_since	str
# 	instant_bookable	str
# 	last_review	str
# 	latitude	float
# 	longitude	float
# 	name	str
# 	neighbourhood	str
# 	number_of_reviews	int
# 	review_scores_rating	float
# 	thumbnail_url	str
# 	zipcode	float
# 	bedrooms	float
# 	beds	float
#
# Rows: 10
#
# Data:
# +----------+---------------+---------------+-----------------+
# |    id    |   log_price   | property_type |    room_type    |
# +----------+---------------+---------------+-----------------+
# | 6901257  |  5.0106352941 |   Apartment   | Entire home/apt |
# | 6304928  | 5.12989871492 |   Apartment   | Entire home/apt |
# | 7919400  | 4.97673374242 |   Apartment   | Entire home/apt |
# | 13418779 | 6.62007320653 |     House     | Entire home/apt |
# | 3808709  | 4.74493212836 |   Apartment   | Entire home/apt |
# | 12422935 | 4.44265125649 |   Apartment   |   Private room  |
# | 11825529 |  4.4188406078 |   Apartment   | Entire home/apt |
# | 13971273 | 4.78749174278 |  Condominium  | Entire home/apt |
# |  180792  | 4.78749174278 |     House     |   Private room  |
# | 5385260  | 3.58351893846 |     House     |   Private room  |
# +----------+---------------+---------------+-----------------+
# +-------------------------------+--------------+-----------+----------+---------------------+
# |           amenities           | accommodates | bathrooms | bed_type | cancellation_policy |
# +-------------------------------+--------------+-----------+----------+---------------------+
# | {"Wireless Internet","Air ... |      3       |    1.0    | Real Bed |        strict       |
# | {"Wireless Internet","Air ... |      7       |    1.0    | Real Bed |        strict       |
# | {TV,"Cable TV","Wireless I... |      5       |    1.0    | Real Bed |       moderate      |
# | {TV,"Cable TV",Internet,"W... |      4       |    1.0    | Real Bed |       flexible      |
# | {TV,Internet,"Wireless Int... |      2       |    1.0    | Real Bed |       moderate      |
# | {TV,"Wireless Internet",He... |      2       |    1.0    | Real Bed |        strict       |
# | {TV,Internet,"Wireless Int... |      3       |    1.0    | Real Bed |       moderate      |
# | {TV,"Cable TV","Wireless I... |      2       |    1.0    | Real Bed |       moderate      |
# | {TV,"Cable TV","Wireless I... |      2       |    1.0    | Real Bed |       moderate      |
# | {"Wireless Internet","Air ... |      2       |    1.0    | Real Bed |       moderate      |
# +-------------------------------+--------------+-----------+----------+---------------------+
# +--------------+------+-------------------------------+--------------+----------------------+
# | cleaning_fee | city |          description          | first_review | host_has_profile_pic |
# +--------------+------+-------------------------------+--------------+----------------------+
# |     True     | NYC  | Beautiful, sunlit brownsto... |  2016-06-18  |          t           |
# |     True     | NYC  | Enjoy travelling during yo... |  2017-08-05  |          t           |
# |     True     | NYC  | The Oasis comes complete w... |  2017-04-30  |          t           |
# |     True     |  SF  | This light-filled home-awa... |              |          t           |
# |     True     |  DC  | Cool, cozy, and comfortabl... |  2015-05-12  |          t           |
# |     True     |  SF  | Beautiful private room ove... |  2017-08-27  |          t           |
# |     True     |  LA  | Warm and cozy studio with ... |  2017-03-10  |          t           |
# |     True     |  LA  | Arguably the best location... |  2016-12-16  |          t           |
# |     True     |  SF  | Garden Studio with private... |  2016-02-13  |          t           |
# |     True     |  LA  | Quiet community. Close to ... |  2017-04-03  |          t           |
# +--------------+------+-------------------------------+--------------+----------------------+
# +------------------------+--------------------+------------+------------------+
# | host_identity_verified | host_response_rate | host_since | instant_bookable |
# +------------------------+--------------------+------------+------------------+
# |           t            |                    | 2012-03-26 |        f         |
# |           f            |        100%        | 2017-06-19 |        t         |
# |           t            |        100%        | 2016-10-25 |        t         |
# |           t            |                    | 2015-04-19 |        f         |
# |           t            |        100%        | 2015-03-01 |        t         |
# |           t            |        100%        | 2017-06-07 |        t         |
# |           f            |        100%        | 2017-03-03 |        t         |
# |           t            |        100%        | 2013-05-18 |        f         |
# |           f            |        100%        | 2015-06-04 |        f         |
# |           f            |        100%        | 2017-03-12 |        t         |
# +------------------------+--------------------+------------+------------------+
# +-------------+---------------+-----+
# | last_review |    latitude   | ... |
# +-------------+---------------+-----+
# |  2016-07-18 |  40.69652363  | ... |
# |  2017-09-23 | 40.7661154159 | ... |
# |  2017-09-14 | 40.8081099894 | ... |
# |             | 37.7720044826 | ... |
# |  2017-01-22 | 38.9256269166 | ... |
# |  2017-09-05 | 37.7531640473 | ... |
# |  2017-04-21 | 33.9804543973 | ... |
# |  2017-04-12 | 34.0467374142 | ... |
# |  2017-09-24 | 37.7811279819 | ... |
# |  2017-04-16 | 33.9925629822 | ... |
# +-------------+---------------+-----+
# [10 rows x 29 columns]

# %%
model = tc.
